# %%
import pandas as pd
import credentials
import numpy as np
import country_converter as coco

# %%
protein_directory = pd.read_csv('raw_protein_directory.csv')

# %%
protein_directory.at[519, 'Location'] = 'Romania'
protein_directory.at[324, 'Location'] = 'United States'
protein_directory.at[328, 'Location'] = 'United States'

# %%
protein_directory.rename(columns={
    'name':'Company', 'summary':'Brief Description', 'link': 'Website', 'End product application':'Company Focus',
    'Protein category':'Protein Category', 'Technology focus':'Technology Focus', 'Location': 'Country', 
    'Ingredients':'Ingredient Type', 'Meat fish analogs':'Animal-Type Analog'
}, inplace=True)
protein_directory
# Out:
#                                             Company  \
# 0                  Global Food and Ingredients Inc.
# 1                              Montana Pure Protein
# 2                                         Alghética
# 3     Shandong Wonderful Industrial Group Co., Ltd.
# 4                            Dahmes Stainless, Inc.
# ...                                             ...
# 1672                                        C-Merak
# 1673                                       GK Foods
# 1674                                       Greenest
# 1675                           Montana Pure Protein
# 1676                                       CP Kelco
#
#                                       Brief Description            Website  \
# 0     GFI is a fast-growing Canadian owned and opera...  gfiglobalfood.com
# 1     We believe in our opportunity to serve a hungr...     montanapure.us
# 2     Alghètica is a biotech startup company involve...      alghetica.com
# ...

# %%
# Create one big dataframe with all GFI data
primary_focus = pd.read_csv('data/CM SOTI_ Primary focus.csv')
manufacturers_and_brands = pd.read_csv('data/WEBSITE VIEW - Manufacturers and brands.csv')
website_view = pd.read_csv('data/Website view.csv')
ingredients_and_equipment = pd.read_csv('data/WEBSITE VIEW_ Ingredients and equipment.csv')
protein = pd.read_csv('data/protein.csv')
milk = pd.read_csv('data/milk.csv')
fungi = pd.read_csv('data/fungi.csv')
algae = pd.read_csv('data/algae.csv')

# %%
primary_focus['Source'] = 'Primary Focus'
manufacturers_and_brands['Source'] = 'Manufacturers and Brands'
ingredients_and_equipment['Source'] = 'Ingredients and Equipment'

# %%
primary_focus = primary_focus[['Company', 'Brief Description', 'Protein Category', 'Company Focus',
       'Technology Focus', 'Product Type', 'Animal-Type Analog',
       'Ingredient Type', 'Operating Regions', 'Country/Province', 'State',
       'City', 'Website', 'Year Founded', 'Founders', 'Logo']]

# %%
gfi = pd.concat([primary_focus, ingredients_and_equipment, manufacturers_and_brands]).drop_duplicates().reset_index(drop=True)
gfi.drop([1328, 546, 1344, 111, 116, 1176], axis=0, inplace=True)
gfi['Website'] = gfi['Website'].str.replace(r'(?:https?:\/\/)', '', regex=True)
gfi['Website'] = gfi['Website'].str.replace(r'(?:www.?)', '', regex=True)
gfi['Website'] = gfi['Website'].str.rstrip('/')
gfi
# Out:
#                               Company  \
# 0                      Agulos Biotech
# 1                         Aleph Farms
# 2                         Alife Foods
# 3                      Ambi Real Food
# 4     Animal Alternative Technologies
# ...                               ...
# 1677                    Armored Fresh
# 1678                   Climate Refarm
# 1679                          Grashka
# 1680                        FERM FOOD
# 1681                Hello Plant Foods
#
#                                       Brief Description  \
# 0     U.S.-based startup developing Simulated Platel...
# 1     Israel-based company producing cultivated beef...
# 2     Germany-based company producing cultured schni...
# 3     Brazil-based company producing cultured meat p...
# 4     U.K.-based company creating a complete, scalab...
# ...                                                 ...
# 1677  Armored Fresh vegan cheese provides flavor and...
# ...

# %%
gfi.rename(columns={'Country/Province':'Country', 'Year Founded': 'Founded'}, inplace=True)

# %%
fungi['Company Focus'] = 'Fungi'
algae['Company Focus'] = 'Algae'
milk['Company Focus'] = 'Dairy'
protein['Company Focus'] = 'Protein'
df_ket = pd.concat([fungi, algae, milk, protein]).drop('src', axis=1).drop_duplicates().reset_index(drop=True)
df_ket.drop([227, 313,341, 749, 506, 41, 464, 747, 907,374, 2, 110, 237, 405, 102, 753, 36, 369, 759, 294, 328, 37, 82, 73, 650, 784, 375, 27, 97, 537, 252, 74, 452, 631, 342, 9, 510, 81, 70, 16, 282, 268, 21, 284, 419, 495, 312, 239, 350, 377, 272, 352, 385,  222, 379, 353, 376, 393, 205], inplace=True)

# %%
df_ket['data_website'] = df_ket['data_website'].str.replace(r'(?:https?:\/\/)', '', regex=True)
df_ket['data_website'] = df_ket['data_website'].str.replace(r'(?:www.?)', '', regex=True)
df_ket['data_website'] = df_ket['data_website'].str.rstrip('/')
df_ket.rename(columns = {'data_founded':'Founded', 'data_founder': 'Founders', 'data_hq': 'Country', 'data_website':'Website'}, inplace = True)

# %%
df_ket['City'] = df_ket['Country'].str.split(',').str[0].str.strip()
df_ket['Country'] = df_ket['Country'].str.split(',').str[-1].str.strip()
df_ket.Country.value_counts()
# Out:
# USA               113
# US                107
# United States      57
# Germany            36
# Canada             26
#                  ...
# Helsinki            1
# RJ                  1
# Haryana             1
# Worcestershire      1
# Jersey              1
# Name: Country, Length: 112, dtype: int64

# %%
all_companies_1 = df_ket.merge(protein_directory, on='Website', how='outer', indicator=True)
all_companies_1.sort_values(by='_merge')
# Out:
#     Founded_x                                           Founders  \
# 712      2016              Gabrielle Radoux et Jurgen Engerisser
# 558      1991                             Wally Fry & Debbie Fry
# 561      1950                                    ‎Ingvar Kamprad
# 562      1994                                         Lee Mee Ng
# 570      2017                                       Iván Jiménez
# ..        ...                                                ...
# 593      2011                                   Patrick O. Brown
# 595      1989                              Colin and Justin Chou
# 596      1989                              Colin and Justin Chou
# 565      2017                                Courtney Boyd Myers
# 0        2020  Juan Pablo De Giacomi; Pablo Sanchez Rey; Fran...
#
#          Country_x               Website Company Focus_x              City  \
# 712         France          pleurette.fr         Protein             Lomme
# ...

# %%
all_companies_2 = all_companies_1.copy()

# %%
# For Founded, Country, Company Focus - if only one available, keep. If two, keep y
#c1 = ((all_companies_1['_merge']=='both') | (all_companies_1['_merge']=='right_only'))
c1_1 = (((all_companies_1['_merge']=='both') & (all_companies_1['Founded_y'].isnull()==False)) | (all_companies_1['_merge']=='right_only'))
c2_1 = (((all_companies_1['_merge']=='both') & (all_companies_1['Founded_y'].isnull()==True)) | (all_companies_1['_merge']=='left_only'))
r1_1 = all_companies_1['Founded_y']
r1_2 = all_companies_1['Founded_x']
conditions1 = [c1_1,c2_1]
results1 = [r1_1,r1_2]
all_companies_1['Founded'] = np.select(conditions1,results1)


c1_2 = (((all_companies_1['_merge']=='both') & (all_companies_1['Country_y'].isnull()==False)) | (all_companies_1['_merge']=='right_only'))
c2_2 = (((all_companies_1['_merge']=='both') & (all_companies_1['Country_y'].isnull()==True)) | (all_companies_1['_merge']=='left_only'))
r2_1 = all_companies_1['Country_y']
r2_2 = all_companies_1['Country_x']
conditions2 = [c1_2,c2_2]
results2 = [r2_1, r2_2]
all_companies_1['Country'] = np.select(conditions2,results2)


c1_3 = (((all_companies_1['_merge']=='both') & (all_companies_1['Company Focus_y'].isnull()==False)) | (all_companies_1['_merge']=='right_only'))
c2_3 = (((all_companies_1['_merge']=='both') & (all_companies_1['Company Focus_y'].isnull()==True)) | (all_companies_1['_merge']=='left_only'))
r3_1 = all_companies_1['Company Focus_y']
r3_2 = all_companies_1['Company Focus_x']
conditions3 = [c1_3,c2_3]
results3 = [r3_1, r3_2]
all_companies_1['Company Focus'] = np.select(conditions3,results3)

all_companies_1
# Out:
#      Founded_x                                           Founders  \
# 0         2020  Juan Pablo De Giacomi; Pablo Sanchez Rey; Fran...
# 1         2010                           Jan Willem Bosman Jansen
# 2         2020                                       Parker Olson
# 3                                                             NaN
# 4                                                             NaN
# ...        ...                                                ...
# 2277       NaN                                                NaN
# 2278       NaN                                                NaN
# 2279       NaN                                                NaN
# 2280       NaN                                                NaN
# 2281       NaN                                                NaN
#
#           Country_x               Website Company Focus_x          City  \
# 0         Argentina         innomy.com.ar           Fungi  Buenos Aires
# ...

# %%
ket_pdir = all_companies_1[['Company', 'Brief Description', 'Founded', 'Founders',
 'Company Focus', 'Primary focus', 'Business model', 'Protein Category', 'Ingredient Type',
 'Technology Focus', 'Animal-Type Analog',  'Website', 'City', 'Country']]
ket_pdir.at[1, 'Country'] = np.NaN
ket_pdir
# Out:
#                  Company                                  Brief Description  \
# 0                 Innomy  Innomy is transforming the farming industry by...
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4                    NaN                                                NaN
# ...                  ...                                                ...
# 2277             Enantis  Enantis s.r.o. is a private company founded in...
# 2278  New Protein Global  New Protein Global believes there are better, ...
# 2279             C-Merak  The world needs protein. At C-Merak, we are dr...
# 2280            GK Foods  End-to-end product managers helping private la...
# 2281            Greenest  Greenest wants to bring about a mammoth change...
#
# ...

# %%
ket_pdir.drop_duplicates(inplace=True)
ket_pdir.at[14, 'Website'] = 'savoreat.com/position/eggnup-ceo'
ket_pdir.at[19, 'Website'] = 'en.cnsoyprotein.cn'
ket_pdir.at[21, 'Website'] = 'facebook.com/Soyatoo'
ket_pdir.drop([15, 17], inplace=True)
ket_pdir[ket_pdir.Website.isnull()]
# Out:
# C:\Users\mpssa\AppData\Local\Temp\ipykernel_21532\1294907293.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ket_pdir.drop_duplicates(inplace=True)
# C:\Users\mpssa\AppData\Local\Temp\ipykernel_21532\1294907293.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ket_pdir.drop([15, 17], inplace=True)
# Empty DataFrame
# Columns: [Company, Brief Description, Founded, Founders, Company Focus, Primary focus, Business model, Protein Category, Ingredient Type, Technology Focus, Animal-Type Analog, Website, City, Country]
# Index: []

# %%
gfi.at[234, 'Website'] = 'en.cnsoyprotein.cn'
gfi.at[371, 'Website'] = 'fujioilusa.com'
gfi.at[384, 'Website']= 'biobetter.bio'
gfi.at[1003, 'Website'] = 'facebook.com/Soyatoo'
gfi.drop([1291], inplace=True)
gfi[gfi.Website.isnull()]
# Out:
#          Company                                  Brief Description  \
# 67  Jimi BioTech  China-based early-stage company that produces ...
# 98   NewDay Farm  China-based company developing 3D food-grade s...
#
#    Protein Category                                    Company Focus  \
# 67       Cultivated                                             Meat
# 98       Cultivated  Meat,Bioprocessing infrastructure and equipment
#
#                                      Technology Focus Product Type  \
# 67  End product formulation and manufacturing,Cell...          NaN
# 98  Cell culture media,Scaffolding and structure,E...          NaN
#
#    Animal-Type Analog Ingredient Type Operating Regions Country State City  \
# 67          Beef/veal           Algae      Asia Pacific   China   NaN  NaN
# 98               Pork             NaN      Asia Pacific   China   NaN  NaN
#
#    Website  Founded Founders Logo Source
# 67     NaN   2021.0      NaN  NaN    NaN
# ...

# %%
all_companies_2 = ket_pdir.merge(gfi, on='Website', how='outer', indicator=True)
all_companies_2.sort_values(by='_merge')
# Out:
#                Company_x                                Brief Description_x  \
# 0                 Innomy  Innomy is transforming the farming industry by...
# 1179           Love Buds                          100% plant-based pleasure
# 1176                Ukko  Ukko is improving the lives of millions that s...
# 1173        ABC Kroos BV  Biorefining of duckweed and other aquatic biom...
# 1172               Circe  Our central mission is to make food people wan...
# ...                  ...                                                ...
# 2238            Goodbite  At GOODBITES, we believe that all food—even sn...
# 2239            24 Vegan                          Produces vegan fish sauce
# 1692             Afineur  Afineur crafts better, healthier and more sust...
# 2226  Kim's Simple Meals  In order to create the healthiest and most del...
# 1468        BIC Services  Soy Proteins are high quality proteins contain...
#
# ...

# %%
columns = {
        'Company':'_y', 
        'Brief Description':'_y',
        'Founders':'_y', 
        'Company Focus':'_x', 
        'Founded':'_x', 
        'Protein Category':'_y',
        'Ingredient Type':'_x',
        'Technology Focus':'_x', 
        'Animal-Type Analog':'_x',
        'Country':'_y', 
        'City':'_y'}

def columns_correction(df, columns):
    
    def condition_label(value, condition):
        
        if value == '_y' and condition == 1:
            return 'right_only'
        elif value == '_y' and condition == 2:
            return 'left_only'
        elif value == '_x' and condition == 1:
            return 'left_only'
        elif value == '_x' and condition == 2:
            return 'right_only'

    labels = {'_y':'right_only', '_x':'left_only'}
    def opposite(value):
        if value == '_y':
            return '_x'
        elif value == '_x':
            return '_y'

    

# Company Y, BRIEF DESCRIPTION Y, Founders y, Company Focus_x, Founded_x, Protein Category_y, Ingredient Type_x,
# Technology Focus_x, Animal-Type Analog_x, Country_y, City_y

    exclude = []
    for i in columns:
        c1 = (((df['_merge']=='both') & (df[i+columns[i]].isnull()==False)) | (df['_merge']==labels[columns[i]]))
        c2 = (((df['_merge']=='both') & (df[i+columns[i]].isnull()==True)) | (df['_merge']==labels[opposite(columns[i])]))
        r1 = df[i+columns[i]]
        r2 = df[i+opposite(columns[i])]
        conditions = [c1,c2]
        results = [r1,r2]
        df[i] = np.select(conditions,results)

        exclude.append(i+'_x')
        exclude.append(i+'_y')
    exclude.append('_merge')
    df = df.drop(columns=exclude)
    
    return df

# %%
all_companies = columns_correction(all_companies_2, columns)
all_companies = all_companies[['Company', 'Brief Description', 'Founded', 'Founders',
 'Company Focus', 'Primary focus', 'Business model', 'Protein Category',
 'Ingredient Type', 'Product Type', 'Technology Focus', 'Animal-Type Analog',
 'Website', 'Operating Regions', 'City', 'Country']]

# %%
#  Clean countries
all_companies['Country'].value_counts()
all_companies.at[376, 'Country'] = 'Japan'
for i in [291, 489, 490, 531]:
    all_companies.at[i, 'Country'] = 'Netherlands'
for i in ['Colorado', 'US', 'USA', 'California', 'United States.', 'WA', 'FL', 'Ohio', 'Michigan','Washington']:
    all_companies.replace({i: 'United States'}, inplace=True)
all_companies.replace({'Sweeden':'Sweden',
'not understood': np.nan,
'Finnland':'Finland',
'The Netherlands':'Netherlands,',
'Haryana':'India',
'Columbia':'Spain',
'Worcestershire': 'United Kingdom',
'Pskov':'Russia',
'British Columbia': 'Canada'
}, inplace=True)

# %%
# Add continent
country_list = list(set(all_companies.Country.to_list()))
country_list.remove(np.nan)
continent_dic = {country: coco.convert(country, to='Continent') for country in country_list}
country_dic = {country: coco.convert(country, to='name_short') for country in country_list}
continent_dic['Scotland'] = 'Europe'
continent_dic['Wales'] = 'Europe'
all_companies['Continent'] = all_companies.Country.map(continent_dic)
all_companies['Country'] = all_companies.Country.map(country_dic)
# Out:
# Scotland not found in regex
# Wales not found in regex
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\mpssa\Documents\Data Portfolio\Alternative Protein companies\alt_protein_companies.ipynb Célula: 23 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/mpssa/Documents/Data%20Portfolio/Alternative%20Protein%20companies/alt_protein_companies.ipynb#X31sZmlsZQ%3D%3D?line=1'>2</a> country_list = list(set(all_companies.Country.to_list()))
#       <a href='vscode-notebook-cell:/c%3A/Users/mpssa/Documents/Data%20Portfolio/Alternative%20Protein%20companies/alt_protein_companies.ipynb#X31sZmlsZQ%3D%3D?line=2'>3</a> country_list.remove(np.nan)
# ...

# %%
no_name = all_companies[all_companies.Company.isnull()].Website.to_list()
with open(r'no_name.txt', 'w') as fp:
    for item in no_name:
        fp.write("%s\n" % item)

# %%
import json

with open('names.json') as f:
   data = json.load(f)

# %%
names_df = pd.DataFrame(data.items(), columns=['Website', 'Company'])
names_df.replace({'Not Acceptable!':np.nan}, inplace=True)
names_df.head(30)
# Out:
#                                        Website  \
# 0                             gro-together.com
# 1                                     forij.co
# 2                         organicmushrooms.com
# 3                            milehighfungi.com
# 4                                fungially.com
# 5                               savorywild.com
# 6                              nhmushrooms.com
# 7                     nutcasevegan.com/recipes
# 8                         columbiamushroom.com
# 9                          sceltamushrooms.com
# 10                      themushroomfactory.com
# 11                     ponderosa-mushrooms.com
# 12                       montereymushrooms.com
# 13  facebook.com/pg/RomanasMushroomFarm/photos
# 14                facebook.com/ValleyCityFungi
# 15                             gramcofungi.com
# 16         facebook.com/chicagomushroomcompany
# 17                           forestfungi.co.uk
# 18                              mamfglobal.com
# ...

# %%
test = all_companies.copy()
all_companies['Company'] = np.where(all_companies.Company.isnull(), 
                                    all_companies['Website'].map(names_df.set_index('Website')['Company']),
                                    all_companies['Company'])
all_companies
# Out:
#                                                 Company  \
# 0                                                Innomy
# 1                        GRO Together - Because we care
# 2     Granola Breakfast | Benefits in Every Bite | F...
# 3     Mother Earth Organic Mushrooms | Organic Whole...
# 4                                       Mile High Fungi
# ...                                                 ...
# 2933                                      Esencia Foods
# 2934                                  Wamame Foods Inc.
# 2935                                      Armored Fresh
# 2936                                            Grashka
# 2937                                  Hello Plant Foods
#
#                                       Brief Description Founded  \
# 0     Innomy is transforming the farming industry by...  2018.0
# 1                                                   NaN    2010
# 2                                                   NaN    2020
# ...

# %%
all_companies.replace({'403 Forbidden':np.nan, '429 Too Many Requests':np.nan}, inplace=True)

# %%
all_companies = all_companies.drop_duplicates()
all_companies.to_csv('all_companies.csv', index=False)

# %%
all_companies_dict = all_companies.to_dict('records')

# %%
from pymongo import MongoClient
from pprint import pprint

# %%
"""client = MongoClient(f"mongodb+srv://{credentials.user}:{credentials.password}@alternativeproteincompa.ai2pysg.mongodb.net/?retryWrites=true&w=majority")
db = client.AlternativeProteinCompanies
companies = db['Companies']
companies.insert_many(all_companies_dict)
db.list_collection_names()"""
# Out:
# 'client = MongoClient("mongodb+srv://maira:qVVRq2Xx2UCBIKVB@alternativeproteincompa.ai2pysg.mongodb.net/?retryWrites=true&w=majority")\ndb = client.AlternativeProteinCompanies\ncompanies = db[\'Companies\']\ncompanies.insert_many(all_companies_dict)\ndb.list_collection_names()'

# %%
# Groupby country and (Technology focus OR End product application OR Protein category)
all_companies.groupby(['Country', 'Technology Focus', 'Ingredient Type', 'Product Type', 'Animal-Type Analog']).Company.nunique().to_frame()
# Out:
#                                                                                                                                                                                                                           Company
# Country       Technology Focus                                   Ingredient Type                                    Product Type                                      Animal-Type Analog
# Australia     End product formulation and manufacturing          Bamboo, Beets, Coconut, Oilseeds, Other, Soy, S... Ground meat                                       Beef/veal,Other                                           1
#                                                                  Lupin, Pea, Soy                                    Cheese,Ground meat,Eggs                           Beef                                                      1
# ...

# %%
tech = all_companies[all_companies['Technology Focus'].map(type).isin([str, list])]
tech_focus = set(tech['Technology Focus'].str.lower().str.split(',').apply(lambda x: [e.strip() for e in x]).sum())
ingr = all_companies[all_companies['Ingredient Type'].map(type).isin([str, list])]
ingredient_type = set(ingr['Ingredient Type'].str.lower().str.split(',').apply(lambda x: [e.strip() for e in x]).sum())
product = all_companies[all_companies['Product Type'].map(type).isin([str, list])]
product_type = set(product['Product Type'].str.lower().str.split(',').apply(lambda x: [e.strip() for e in x]).sum())
analog = all_companies[all_companies['Animal-Type Analog'].map(type).isin([str, list])]
animal_type_analog = set(analog['Animal-Type Analog'].str.lower().str.split(',').apply(lambda x: [e.strip() for e in x]).sum())

# %%
# Improve country column
a

# %%
# Out:
#                                                Company Brief Description  \
# 768                                  Welcome to Pevesa               NaN
# 857  CNTA | Tecnología y conocimiento para la compe...               NaN
#
#     Founded Founders Company Focus Primary focus Business model  \
# 768    1996      NaN       Protein           NaN            NaN
# 857    1981      NaN       Protein           NaN            NaN
#
#     Protein Category Ingredient Type Product Type Technology Focus  \
# 768              NaN             NaN          NaN              NaN
# 857              NaN             NaN          NaN              NaN
#
#     Animal-Type Analog     Website Operating Regions  \
# 768                NaN  pevesa.com               NaN
# 857                NaN  cnta.es/en               NaN
#
#                            City Country Continent
# 768  El Viso del Alcor  Seville      ES    Europe
# 857         San Adrian  Navarre      ES    Europe

# %%
# Count the number of times one of these words appear in a country
# Graph and list places with opportunities - suggestions
# Create new dataframe with funding amounts
# Out:
# ['3d printing', 'biomass fermentation', 'bioprocess design', 'cell culture media', 'cell line development', 'crop development', 'end product formulation and manufacturing', 'extrusion', 'feedstocks', 'gas fermentation', 'high moisture extrusion', 'host strain development', 'ingredient optimization', 'low moisture extrusion', 'precision fermentation', 'scaffolding and structure', 'shear cell extrusion', 'solid state fermentation', 'target molecule selection', 'traditional fermentation'] 20

# %%
all_companies.groupby(['Country', 'Technology Focus']).Company.nunique().to_frame()
# Out:
#                                                                   Company
# Country       Technology Focus
# Argentina     Biomass fermentation                                      1
#               Bioprocess design                                         1
#               End product formulation and manufacturing                 1
#               Ingredient optimization                                   2
#               Ingredient optimization, Precision fermentation           1
# ...                                                                   ...
# United States Target molecule selection,End product formulati...        3
#               Traditional fermentation                                  2
# Venezuela     End product formulation and manufacturing                 2
# Vietnam       End product formulation and manufacturing                 1
# latvia        End product formulation and manufacturing                 1
#
# [387 rows x 1 columns]

# %%
all_companies.groupby(['Country', 'Ingredient Type']).Company.nunique().to_frame()
# Out:
#                                                       Company
# Country       Ingredient Type
# Argentina     Almond, Blend, Coconut, Oat, Rice, Soy        1
#               Carrots                                       1
#               Coconut,Almond                                1
#               Fungi, Fusarium venenatum                     2
#               Soy                                           1
# ...                                                       ...
# United States hydrogenotrophs                               1
# Venezuela     Almond                                        1
#               Cashew                                        1
# Vietnam       Cashew                                        2
# latvia        Pea                                           1
#
# [1204 rows x 1 columns]

# %%
all_companies.groupby(['Country', 'Product Type']).Company.nunique().to_frame()
# Out:
#                                                                   Company
# Country       Product Type
# Argentina     Cheese                                                    1
#               Cheese,Milk,Ground meat,Whole muscle meat,Eggs            1
#               Ingredients                                               2
# Australia     Cheese,Ground meat,Eggs                                   1
#               Eggs                                                      3
# ...                                                                   ...
# United States Whole muscle meat,Ground meat,Other meat,Ingred...        1
#               Whole muscle meat,Other meat                              2
# Venezuela     Cheese                                                    1
#               Milk,Other dairy                                          1
# Vietnam       Cheese,Other                                              1
#
# [453 rows x 1 columns]

# %%
all_companies.groupby(['Country', 'Animal-Type Analog']).Company.nunique().to_frame()
# Out:
#                                                                   Company
# Country       Animal-Type Analog
# Argentina     Beef                                                      2
# Australia     Beef                                                      5
#               Beef, Calamari, Caviar, Chicken, Crab, Duck, Ee...        1
#               Beef, Chicken, Lamb, Pork, Poultry                        1
#               Beef, Chicken, Pork, Poultry                              1
# ...                                                                   ...
# United States Tuna,Beef/veal,Pork                                       1
#               Tuna,Fish                                                 1
#               Tuna,Other                                                1
#               Tuna,Shellfish,Fish                                       1
# latvia        Fish,Tuna                                                 1
#
# [432 rows x 1 columns]

# %%
# Graph and list places with opportunities - suggestions

# %%
# See and exclude duplicates based on name of company
all_companies


# Groupby country and (Technology focus OR End product application OR Protein category)

# %% [markdown]
# Protein directory
# - Drop Meat fish analogs
# - Replace:
# 'name':'Company', 'summary':'Brief Description', 'link': 'Website', End product application':'Company Focus',  'Protein category':'Protein Category', 'Technology focus':'Technology Focus', 'Location: 'Country', 'Ingredients':'Ingredient Type', 'Meat fish analogs':'Animal-Type Analog'
#
# KET
# 'data_founded':'Founded', 'data_founder':	'data_hq': 'Location', 'data_website':'Website', Company Focus
#
# GFI
#
# Product Type
# Animal-Type Analog
# Ingredient Type
# Operating Regions
#
# State
# City
#
# 'Country/Province':'Country'
# 'Year Founded': 'Founded'
# Founders
#
# FInal
# Company Description Website Primary Focus Country Founded Business Model Protein Caategory Ingredients, 'Technology Focus', 'End Product Application', 'Continent'

# %%
protein_directory
# Out:
#                                                name  \
# 0                  Global Food and Ingredients Inc.
# 1                              Montana Pure Protein
# 2                                         Alghética
# 3     Shandong Wonderful Industrial Group Co., Ltd.
# 4                            Dahmes Stainless, Inc.
# ...                                             ...
# 1672                                        C-Merak
# 1673                                       GK Foods
# 1674                                       Greenest
# 1675                           Montana Pure Protein
# 1676                                       CP Kelco
#
#                                                 summary               link  \
# 0     GFI is a fast-growing Canadian owned and opera...  gfiglobalfood.com
# 1     We believe in our opportunity to serve a hungr...     montanapure.us
# 2     Alghètica is a biotech startup company involve...      alghetica.com
# ...

# %%
# We can make a dashboard where can see country and operating regions (maps); ingredient type; animal type analog and protein category
# Also show year founded. 
# Check how often they were mentioned in the news and present dataframe or graph

# What words they repeat in their names 
#Name generator? 


# Few rows, so check if Tom's website has this info - Investment breakdown and Underfunded areas)
